# %%
import matplotlib.pyplot as plt
import numpy as np
import math, copy
import scipy
# from pylab import *
from matplotlib import cm

# %% [markdown]
# # Data

# %%
##############################################
#    Batch 0
##############################################
#8_models models
samplesize_b0_m8_models = [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0]
dimensions_b0_m8_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b0_m8_models = [21.656, 21.392, 21.572, 22.623, 22.552, 21.497, 21.452, 22.03, 22.749, 22.533, 20.577, 22.019, 20.406, 21.518, 21.562, 21.524, 22.488, 22.396, 21.059, 21.618, 20.842, 21.591, 21.919, 21.791, 4.423, 4.245, 4.561, 4.3, 4.249, 4.325, 4.267, 4.514, 4.167, 4.241, 4.266, 4.224, 4.429, 4.43, 4.28, 4.482, 4.269, 4.516, 4.337, 4.265, 4.21, 4.497, 4.294, 4.314, 1.102, 1.026, 1.094, 1.095, 1.023, 1.082, 1.104, 1.029, 1.094, 1.078, 1.036, 1.129, 1.025, 1.047, 1.127, 1.042, 1.075, 1.093, 1.051, 1.086, 1.091, 1.072, 1.107, 1.075]
f1_b0_m8_models = [0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.847, 0.87, 0.861, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.845, 0.877, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863, 0.825, 0.88, 0.863]

#4_models models
samplesize_b0_m4_models = [400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0]
dimensions_b0_m4_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b0_m4_models = [67.286, 65.951, 68.04, 65.959, 65.594, 66.761, 66.141, 66.236, 66.864, 66.89, 67.01, 66.24, 15.518, 15.472, 15.569, 15.486, 15.333, 15.495, 15.25, 15.574, 15.505, 15.579, 15.578, 15.316, 3.695, 3.678, 3.695, 3.691, 3.668, 3.689, 3.655, 3.776, 3.731, 3.714, 3.733, 3.702]
f1_b0_m4_models = [0.891, 0.888, 0.903, 0.891, 0.888, 0.903, 0.891, 0.888, 0.903, 0.891, 0.888, 0.903, 0.89, 0.902, 0.879, 0.89, 0.902, 0.879, 0.89, 0.902, 0.879, 0.89, 0.902, 0.879, 0.886, 0.877, 0.893, 0.886, 0.877, 0.893, 0.886, 0.877, 0.893, 0.886, 0.877, 0.893]

#2_models models
samplesize_b0_m2_models = [800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0]
dimensions_b0_m2_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b0_m2_models = [233.496, 230.397, 232.885, 230.481, 235.052, 230.225, 57.572, 57.753, 57.283, 57.4, 57.786, 57.024, 14.14, 14.129, 14.17, 14.212, 14.255, 14.241]
f1_b0_m2_models = [0.915, 0.932, 0.942, 0.915, 0.932, 0.942, 0.905, 0.932, 0.925, 0.905, 0.932, 0.925, 0.897, 0.914, 0.915, 0.897, 0.914, 0.915]

#1_models models
samplesize_b0_m1_models = [1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0]
dimensions_b0_m1_models = [109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0]
traintime_b0_m1_models = [873.451, 872.806, 873.382, 221.146, 221.284, 221.921, 53.984, 54.109, 54.198]
f1_b0_m1_models = [0.951, 0.951, 0.951, 0.94, 0.94, 0.94, 0.9, 0.9, 0.9]

# %%
##############################################
#    Batch 1
##############################################
#8_models models
samplesize_b1_m8_models = [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0]
dimensions_b1_m8_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b1_m8_models = [22.609, 22.789, 22.71, 22.052, 22.643, 22.712, 22.628, 22.692, 22.715, 22.721, 21.877, 22.854, 21.811, 22.697, 22.678, 22.891, 22.67, 22.68, 22.858, 22.372, 22.938, 22.788, 22.591, 21.906, 4.367, 4.474, 4.444, 4.598, 4.22, 4.427, 4.392, 4.521, 4.019, 4.41, 4.15, 4.374, 4.215, 4.198, 4.088, 4.285, 4.313, 4.369, 4.524, 4.4, 4.43, 4.572, 4.287, 4.187, 1.086, 1.076, 1.11, 1.078, 1.086, 1.12, 1.07, 1.103, 1.101, 1.087, 1.085, 1.069, 1.065, 1.09, 1.108, 1.064, 1.085, 1.067, 1.07, 1.056, 1.079, 1.107, 1.044, 1.058]
f1_b1_m8_models = [0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.82, 0.867, 0.816, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.807, 0.862, 0.809, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814, 0.81, 0.852, 0.814]

#4_models models
samplesize_b1_m4_models = [400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0]
dimensions_b1_m4_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b1_m4_models = [66.429, 67.585, 66.51, 67.452, 66.166, 66.784, 64.905, 65.555, 66.383, 67.647, 66.098, 66.157, 15.503, 15.425, 15.517, 15.509, 15.257, 15.588, 15.36, 15.486, 15.461, 15.632, 15.519, 15.301, 3.746, 3.718, 3.72, 3.707, 3.72, 3.708, 3.625, 3.765, 3.774, 3.841, 3.733, 3.71]
f1_b1_m4_models = [0.897, 0.91, 0.909, 0.897, 0.91, 0.909, 0.897, 0.91, 0.909, 0.897, 0.91, 0.909, 0.892, 0.905, 0.901, 0.892, 0.905, 0.901, 0.892, 0.905, 0.901, 0.892, 0.905, 0.901, 0.92, 0.882, 0.85, 0.92, 0.882, 0.85, 0.92, 0.882, 0.85, 0.92, 0.882, 0.85]

#2_models models
samplesize_b1_m2_models = [800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0]
dimensions_b1_m2_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b1_m2_models = [232.321, 233.229, 233.269, 231.556, 233.015, 230.776, 57.412, 57.396, 57.216, 57.689, 57.717, 57.719, 14.461, 14.199, 14.332, 14.307, 14.42, 14.428]
f1_b1_m2_models = [0.933, 0.932, 0.93, 0.933, 0.932, 0.93, 0.92, 0.934, 0.911, 0.92, 0.934, 0.911, 0.87, 0.932, 0.897, 0.87, 0.932, 0.897]

#1_models models
samplesize_b1_m1_models = [1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0]
dimensions_b1_m1_models = [109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0]
traintime_b1_m1_models = [874.202, 887.441, 871.679, 221.598, 222.077, 220.707, 54.448, 54.299, 54.273]
f1_b1_m1_models = [0.952, 0.952, 0.952, 0.937, 0.937, 0.937, 0.908, 0.908, 0.908]

# %%
##############################################
#    Batch 2
##############################################
#8_models models
samplesize_b2_m8_models = [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0]
dimensions_b2_m8_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b2_m8_models = [22.545, 22.74, 21.847, 22.307, 21.834, 21.526, 21.685, 22.275, 22.075, 22.057, 21.322, 22.067, 21.575, 22.534, 21.846, 22.076, 22.043, 21.991, 21.342, 21.58, 22.156, 21.741, 21.696, 21.355, 4.521, 4.315, 4.361, 4.424, 4.187, 4.38, 4.42, 4.151, 4.511, 4.421, 4.493, 4.365, 4.436, 4.416, 4.41, 4.482, 4.425, 4.376, 4.399, 4.455, 4.395, 4.527, 4.353, 4.329, 1.048, 1.037, 1.108, 1.057, 1.016, 1.092, 1.075, 1.037, 1.109, 1.06, 1.053, 1.093, 1.059, 1.044, 1.135, 1.067, 1.044, 1.079, 1.064, 1.026, 1.094, 1.057, 1.111, 1.083]
f1_b2_m8_models = [0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.849, 0.893, 0.872, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.843, 0.874, 0.865, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855, 0.836, 0.88, 0.855]

#4_models models
samplesize_b2_m4_models = [400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0]
dimensions_b2_m4_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b2_m4_models = [68.4, 67.363, 67.114, 67.966, 65.976, 68.341, 66.763, 67.748, 67.653, 67.923, 67.973, 66.999, 15.552, 15.371, 15.4, 15.408, 15.302, 15.432, 15.336, 15.605, 15.495, 15.557, 15.48, 15.214, 3.699, 3.761, 3.716, 3.701, 3.679, 3.696, 3.738, 3.732, 3.764, 3.752, 3.726, 3.684]
f1_b2_m4_models = [0.905, 0.881, 0.903, 0.905, 0.881, 0.903, 0.905, 0.881, 0.903, 0.905, 0.881, 0.903, 0.903, 0.889, 0.885, 0.903, 0.889, 0.885, 0.903, 0.889, 0.885, 0.903, 0.889, 0.885, 0.865, 0.891, 0.876, 0.865, 0.891, 0.876, 0.865, 0.891, 0.876, 0.865, 0.891, 0.876]

#2_models models
samplesize_b2_m2_models = [800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0]
dimensions_b2_m2_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b2_m2_models = [232.542, 231.905, 233.291, 231.963, 234.409, 232.444, 58.035, 57.187, 57.993, 58.633, 57.526, 57.535, 14.391, 14.312, 14.358, 14.395, 14.452, 14.417]
f1_b2_m2_models = [0.916, 0.925, 0.918, 0.916, 0.925, 0.918, 0.924, 0.923, 0.926, 0.924, 0.923, 0.926, 0.896, 0.949, 0.896, 0.896, 0.949, 0.896]

#1_models models
samplesize_b2_m1_models = [1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0]
dimensions_b2_m1_models = [109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0]
traintime_b2_m1_models = [846.84, 874.245, 876.482, 220.384, 220.636, 220.454, 54.158, 54.129, 54.086]
f1_b2_m1_models = [0.956, 0.956, 0.956, 0.94, 0.94, 0.94, 0.913, 0.913, 0.913]

# %%
##############################################
#    Batch 3
##############################################
#8_models models
samplesize_b3_m8_models = [200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0, 200.0, 198.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 198.0]
dimensions_b3_m8_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b3_m8_models = [22.583, 21.733, 21.221, 22.193, 22.188, 21.5, 22.292, 21.346, 21.309, 22.27, 20.359, 22.051, 21.776, 20.957, 21.035, 21.515, 21.492, 21.497, 21.295, 22.647, 21.202, 21.453, 21.298, 21.085, 4.33, 4.286, 4.353, 4.353, 4.313, 4.303, 4.464, 4.327, 4.308, 4.371, 4.238, 4.33, 4.237, 4.401, 4.411, 4.264, 4.326, 4.321, 4.303, 4.358, 4.273, 4.318, 4.291, 4.279, 1.095, 1.063, 1.118, 1.088, 1.081, 1.098, 1.094, 1.081, 1.077, 1.082, 1.078, 1.064, 1.079, 1.074, 1.096, 1.109, 1.111, 1.078, 1.092, 1.098, 1.085, 1.11, 1.104, 1.093]
f1_b3_m8_models = [0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.872, 0.858, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.867, 0.864, 0.859, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856, 0.849, 0.836, 0.856]

#4_models models
samplesize_b3_m4_models = [400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0, 400.0, 398.0, 400.0, 400.0, 400.0, 400.0, 398.0]
dimensions_b3_m4_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b3_m4_models = [66.539, 67.635, 67.176, 65.335, 64.85, 65.138, 65.605, 67.231, 66.543, 66.579, 65.433, 65.681, 15.486, 15.34, 15.426, 15.523, 15.345, 15.484, 15.182, 15.463, 15.555, 15.725, 15.489, 15.263, 3.675, 3.658, 3.692, 3.726, 3.804, 3.715, 3.692, 3.819, 3.737, 3.748, 3.722, 3.694]
f1_b3_m4_models = [0.893, 0.891, 0.894, 0.893, 0.891, 0.894, 0.893, 0.891, 0.894, 0.893, 0.891, 0.894, 0.877, 0.891, 0.907, 0.877, 0.891, 0.907, 0.877, 0.891, 0.907, 0.877, 0.891, 0.907, 0.877, 0.905, 0.888, 0.877, 0.905, 0.888, 0.877, 0.905, 0.888, 0.877, 0.905, 0.888]

#2_models models
samplesize_b3_m2_models = [800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0, 800.0, 798.0]
dimensions_b3_m2_models = [109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0, 6832.0]
traintime_b3_m2_models = [231.954, 230.282, 230.353, 231.681, 231.671, 230.629, 57.647, 56.694, 56.706, 57.53, 57.741, 57.365, 14.164, 14.216, 14.203, 14.253, 14.357, 14.194]
f1_b3_m2_models = [0.925, 0.944, 0.926, 0.925, 0.944, 0.926, 0.904, 0.956, 0.914, 0.904, 0.956, 0.914, 0.896, 0.913, 0.89, 0.896, 0.913, 0.89]

#1_models models
samplesize_b3_m1_models = [1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0, 1598.0]
dimensions_b3_m1_models = [109319.0, 109319.0, 109319.0, 27329.0, 27329.0, 27329.0, 6832.0, 6832.0, 6832.0]
traintime_b3_m1_models = [871.592, 871.109, 872.448, 220.838, 221.206, 219.983, 54.035, 54.31, 54.073]
f1_b3_m1_models = [0.955, 0.955, 0.955, 0.942, 0.942, 0.942, 0.91, 0.91, 0.91]

# %%
samplesize_m1 = samplesize_b0_m1_models
samplesize_m1.extend(samplesize_b1_m1_models)
samplesize_m1.extend(samplesize_b2_m1_models)
samplesize_m1.extend(samplesize_b3_m1_models)

dimensions_m1 = dimensions_b0_m1_models
dimensions_m1.extend(dimensions_b1_m1_models)
dimensions_m1.extend(dimensions_b2_m1_models)
dimensions_m1.extend(dimensions_b3_m1_models)

traintime_m1 = traintime_b0_m1_models
traintime_m1.extend(traintime_b1_m1_models)
traintime_m1.extend(traintime_b2_m1_models)
traintime_m1.extend(traintime_b3_m1_models)

f1_m1 = f1_b0_m1_models
f1_m1.extend(f1_b1_m1_models)
f1_m1.extend(f1_b2_m1_models)
f1_m1.extend(f1_b3_m1_models)


samplesize_m2 = samplesize_b0_m2_models
samplesize_m2.extend(samplesize_b1_m2_models)
samplesize_m2.extend(samplesize_b2_m2_models)
samplesize_m2.extend(samplesize_b3_m2_models)

dimensions_m2 = dimensions_b0_m2_models
dimensions_m2.extend(dimensions_b1_m2_models)
dimensions_m2.extend(dimensions_b2_m2_models)
dimensions_m2.extend(dimensions_b3_m2_models)

traintime_m2 = traintime_b0_m2_models
traintime_m2.extend(traintime_b1_m2_models)
traintime_m2.extend(traintime_b2_m2_models)
traintime_m2.extend(traintime_b3_m2_models)

f1_m2 = f1_b0_m2_models
f1_m2.extend(f1_b1_m2_models)
f1_m2.extend(f1_b2_m2_models)
f1_m2.extend(f1_b3_m2_models)



samplesize_m4 = samplesize_b0_m4_models
samplesize_m4.extend(samplesize_b1_m4_models)
samplesize_m4.extend(samplesize_b2_m4_models)
samplesize_m4.extend(samplesize_b3_m4_models)

dimensions_m4 = dimensions_b0_m4_models
dimensions_m4.extend(dimensions_b1_m4_models)
dimensions_m4.extend(dimensions_b2_m4_models)
dimensions_m4.extend(dimensions_b3_m4_models)

traintime_m4 = traintime_b0_m4_models
traintime_m4.extend(traintime_b1_m4_models)
traintime_m4.extend(traintime_b2_m4_models)
traintime_m4.extend(traintime_b3_m4_models)

f1_m4 = f1_b0_m4_models
f1_m4.extend(f1_b1_m4_models)
f1_m4.extend(f1_b2_m4_models)
f1_m4.extend(f1_b3_m4_models)



samplesize_m8 = samplesize_b0_m8_models
samplesize_m8.extend(samplesize_b1_m8_models)
samplesize_m8.extend(samplesize_b2_m8_models)
samplesize_m8.extend(samplesize_b3_m8_models)

dimensions_m8 = dimensions_b0_m8_models
dimensions_m8.extend(dimensions_b1_m8_models)
dimensions_m8.extend(dimensions_b2_m8_models)
dimensions_m8.extend(dimensions_b3_m8_models)

traintime_m8 = traintime_b0_m8_models
traintime_m8.extend(traintime_b1_m8_models)
traintime_m8.extend(traintime_b2_m8_models)
traintime_m8.extend(traintime_b3_m8_models)

f1_m8 = f1_b0_m8_models
f1_m8.extend(f1_b1_m8_models)
f1_m8.extend(f1_b2_m8_models)
f1_m8.extend(f1_b3_m8_models)

# %%
fig_path = 'figs/'

# %% [markdown]
# ## Calculating STD and Mean for Error

# %%
# 3. F1 score vs input dim

import statistics as st
# i want to plot the f1 score vs input dimensions, but instead of scatter, using error bars for each input dim value
# so i need to calculate the mean and std of the f1 score for each input dim value

f1_m1_d = dict()
f1_m1_d[109319] = []
f1_m1_d[27329] = []
f1_m1_d[6832] = []

for i in range(len(f1_m1)):
    if dimensions_m1[i] == 109319.0:
        f1_m1_d[109319].append(f1_m1[i])
    elif dimensions_m1[i] == 27329.0:
        f1_m1_d[27329].append(f1_m1[i])
    else :
        f1_m1_d[6832].append(f1_m1[i])
    
f1_m1_points = [st.mean(f1_m1_d[x]) for x in f1_m1_d.keys()]
f1_m1_error = [st.stdev(f1_m1_d[x]) for x in f1_m1_d.keys()]


f1_m2_d = dict()
f1_m2_d[109319] = []
f1_m2_d[27329] = []
f1_m2_d[6832] = []

for i in range(len(f1_m2)):
    if dimensions_m2[i] == 109319.0:
        f1_m2_d[109319].append(f1_m2[i])
    elif dimensions_m2[i] == 27329.0:
        f1_m2_d[27329].append(f1_m2[i])
    else :
        f1_m2_d[6832].append(f1_m2[i])
        
f1_m2_points = [st.mean(f1_m2_d[x]) for x in f1_m2_d.keys()]
f1_m2_error = [st.stdev(f1_m2_d[x]) for x in f1_m2_d.keys()]


f1_m4_d = dict()
f1_m4_d[109319] = []
f1_m4_d[27329] = []
f1_m4_d[6832] = []

for i in range(len(f1_m4)):
    if dimensions_m4[i] == 109319.0:
        f1_m4_d[109319].append(f1_m4[i])
    elif dimensions_m4[i] == 27329.0:
        f1_m4_d[27329].append(f1_m4[i])
    else :
        f1_m4_d[6832].append(f1_m4[i])

f1_m4_points = [st.mean(f1_m4_d[x]) for x in f1_m4_d.keys()]
f1_m4_error = [st.stdev(f1_m4_d[x]) for x in f1_m4_d.keys()]


f1_m8_d = dict()
f1_m8_d[109319] = []
f1_m8_d[27329] = []
f1_m8_d[6832] = []

for i in range(len(f1_m8)):
    if dimensions_m8[i] == 109319.0:
        f1_m8_d[109319].append(f1_m8[i])
    elif dimensions_m8[i] == 27329.0:
        f1_m8_d[27329].append(f1_m8[i])
    else :
        f1_m8_d[6832].append(f1_m8[i])
        
f1_m8_points = [st.mean(f1_m8_d[x]) for x in f1_m8_d.keys()]
f1_m8_error = [st.stdev(f1_m8_d[x]) for x in f1_m8_d.keys()]

# %% [markdown]
# # Plotting

# %%
# 1. Training time vs input dim
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(dimensions_m1, traintime_m1, color='blue', label='1 model')
ax.scatter(dimensions_m2, traintime_m2, color='orange', label='2 models' )
ax.scatter(dimensions_m4, traintime_m4, color='red', label='4 models')
ax.scatter(dimensions_m8, traintime_m8, color='green', label='8 models')
ax.set_xlabel('Input dimensions')
ax.set_ylabel('Training time (seconds)')
ax.set_title('Training time vs input dimensions')
ax.legend(loc='upper left')
plt.savefig(fig_path + 'traintime_vs_dimension.pdf', format='pdf', dpi=1000)
plt.show()

# %%
# 2. Training time vs # of labels
fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(samplesize_m1[0], st.mean(traintime_m1), st.stdev(traintime_m1), fmt='o', color='blue', label='1 model')
ax.errorbar(samplesize_m2[0], st.mean(traintime_m2), st.stdev(traintime_m2), fmt='o', color='orange', label='2 models')
ax.errorbar(samplesize_m4[0], st.mean(traintime_m4), st.stdev(traintime_m4), fmt='o', color='red', label='4 models')
ax.errorbar(samplesize_m8[0], st.mean(traintime_m8), st.stdev(traintime_m8), fmt='o', color='green', label='8 models')
ax.set_xlabel('Number of labels')
ax.set_ylabel('Training time (seconds)')
ax.set_title('Training time vs number of labels')
ax.legend(loc='upper left')
plt.savefig(fig_path + 'traintime_vs_samplesize.pdf', format='pdf', dpi=1000)
plt.show()

# %%
# 3. F1 score vs input dim
fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(f1_m1_d.keys(), f1_m1_points, f1_m1_error, fmt='o', color='blue', label='1 model')
ax.errorbar(f1_m2_d.keys(), f1_m2_points, f1_m2_error, fmt='o', color='orange', label='2 models' )
ax.errorbar(f1_m4_d.keys(), f1_m4_points, f1_m4_error, fmt='o', color='red', label='4 models')
ax.errorbar(f1_m8_d.keys(), f1_m8_points, f1_m8_error, fmt='o', color='green', label='8 models')
ax.set_xlabel('Input dimensions')
ax.set_ylabel('F1 score')
ax.set_title('F1 score vs input dimensions')
fig.legend(loc='outside left upper')
fig.tight_layout(pad=5)
fig.savefig(fig_path + 'f1_vs_dimension.pdf', format='pdf', dpi=1000)
plt.show()

# %%
# 4. F1 vs # of labels

fig = plt.figure()
ax = fig.add_subplot(111)
# create error bars
ax.errorbar(samplesize_m1[0], st.mean(f1_m1), st.stdev(f1_m1), fmt='o', color='blue', label='1 model')
ax.errorbar(samplesize_m2[0], st.mean(f1_m2), st.stdev(f1_m2), fmt='o', color='orange', label='2 models' )
ax.errorbar(samplesize_m4[0], st.mean(f1_m4), st.stdev(f1_m4), fmt='o', color='red', label='4 models')
ax.errorbar(samplesize_m8[0], st.mean(f1_m8), st.stdev(f1_m8), fmt='o', color='green', label='8 models')

ax.set_xlabel('Number of labels')
ax.set_ylabel('F1')
ax.set_title('F1 vs number of labels')
ax.legend(loc='upper left')
plt.savefig(fig_path + 'f1_vs_samplesize.pdf', format='pdf', dpi=1000)
plt.show()
